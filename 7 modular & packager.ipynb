# %%
# Online Python compiler (interpreter) to run Python online.
# Write Python 3 code in this online editor and run it.
print("Try programiz.pro")
print("=====================================")
print("Welcome to Multi-utility Toolkit")
print("=====================================")
# Main menu
def modular_packager():
    while True:
        print("\n---Main menu---")
        print("choose an operation:")
        print("1. Date and Time operation")
        print("2. Mathematical operation")
        print("3. Random Data Generator")
        print("4. Generate unique identifiers(UUID)")
        print("5. File operations (custom module)")
        print("6. Explore module attributes (dir())")
        print("7. Exit")
        

        choice = int(input("Enter your choice:"))

        if choice == 1:
            date_time_operations()
    
        elif choice == 2:
            mathematcal_operator()
            
        elif choice == 3:
            randoms()
            
        elif choice == 4:
            identifiers()
            
        elif choice == 5:
            file()
            
        elif choice == 6:
            modules()
            
        elif choice == 7:
            print("\nExiting the sysytem. All resources have been freed.")
            print("Goodbye!👋👋👋")
            break
    
        else:
            print("Invalid choice. Please try again🤦.\n")
            break
    
        
        
    
    
import datetime
import time
def date_time_operations():
    while True:
        print("\nDate and Time operation")
        print("1. Display current date and time")
        print("2. calculate difference between two dates")
        print("3. format date into custom format")
        print("4. stopwatch")
        print("5. countdown timer")
        print("6. back to main menu")
        
        choice = int(input("Enter your choice:"))
        
        if choice == 1:
            now = datetime.datetime.now()
            d = now.strftime("%Y-%m-%d %H:%M:%S")
            print("Current date and time:", d)
            
        elif choice == 2:
            f_date = input("Enter first date(YYYY-MM-DD):")
            date1 = datetime.datetime.strptime(f_date,"%Y-%m-%d")
            
            s_date = input("Enter second date(YYYY-MM-DD):")
            date2 = datetime.datetime.strptime(s_date, "%Y-%m-%d")
            
            dt = date2 - date1
            print("difference:",dt)

        elif choice == 3:

            custom =datetime.datetime.now()
            print("custom format is:",custom)

        elif choice == 4:
            start = time.time()
            input("press enter to start a time")
            
            
            input("press enter to stop a time")
            end = time.time()
            print("elapse time is:", round(end - start, 2), "second")
            
        elif choice == 5:
            sec = int(input("Enter a second for countdown:"))
            while sec > 0:
                print(sec)
                sec = sec - 1
            print("Time is up!")
            
        elif choice == 6:
            return
            
            
            
        else:
            print("invalid choice, Try again")
            break


import math
def mathematcal_operator():
    while True:
        print("\nmathematcal_operator")
        print("1. Calculate factorial")
        print("2. Solve compound interest")
        print("3. Trignometric calculations")
        print("4. Area of geomatric shapes")
        print("5. back to main menu")
        
        choice = int(input("Enter your choice:"))

        if choice == 1:
            fact = int(input("Enter number to find factorial:"))
            print(f"factorial of {fact} is",math.factorial(fact))

        elif choice == 2:
            amount = int(input("Enter principal amount:"))
            interest = int(input("enter rate of interest"))
            time = int(input("Enter time:"))
            a = amount*(pow((1+interest/100),time))
            compound_interest = a-amount
            print(compound_interest)

        elif choice == 3:
            num = int(input("Enter value in radian:"))
            print(f"sin {num} is:",math.sin(num))
            print(f"cos {num} is:",math.cos(num))
            print(f"tan {num} is:",math.tan(num))
            
        elif choice == 4:
            print("calculate radius:")
            rad = int(input("Enter radius:"))
            print("radius is:", math.pi * rad *rad)
            
            print("\ncalculate square area:")
            sqr_area = int(input("Enter the value of a:"))
            print("area of square is:", sqr_area * sqr_area)
        
            print("\ncalculate rectangle:")
            length = int(input("Enter length: "))
            width = int(input("Enter width:"))
            print("area of rectangle is:", length*width)

        elif choice == 5:
            return
        else:
            print("Enter correct choice")
            break


import random
import string
def randoms():
    print("\nRandom Data Generator:")
    while True:
        print("1. Generate random number:")
        print("2. Generate random list")
        print("3. Create random password")
        print("4. Generate random OTP")
        print("5. Back to main menu")

        choice = int(input("Enter your choice:"))

        if choice == 1:
            print("----Generate random number----")
            first = int(input("Enter first number: "))
            last = int(input("Enter last number: "))
            print(f"randomly generate number between {first} and {last} is:" ,random.randint(first, last))

        elif choice == 2:
            print("----Generate random list----")
            lst = input("Enter name sperate by space:")
            a = lst.split()
            print(a)
            print(random.choice(a))

        elif choice == 3:
            letters = string.ascii_letters  
            digits = string.digits          
               
            all_chars = letters + digits 
            password_length = 10
            password = ''.join(random.choice(all_chars) for _ in range(password_length))
            print("Random Password:", password)
            
        elif choice == 4:
            otp_length = 6

            otp = "".join(str(random.randint(0,9))for _ in range(otp_length))
            print(otp)

        elif choice == 5:
            return
        else:
            print("Enter correct choice")
            break

import uuid
def identifiers():
    print("Generate unique identifiers:")
    p = uuid.uuid4()
    print(p)
    

def file():
    print("\n----File operation----")
    while True:
        print("1. create a new file")
        print("2. write to a file")
        print("3. read from a file")
        print("4. append to a file")
        print("5. back to main menu")

        choice = int(input("Enter a choice: "))

        if choice == 1:
            file_name = input("Enter file name with extension:")
            f = open(file_name, "w")
            f.close()
            print("File created successfully")

        elif choice == 2:
            file_name = input("Enter file name with extension:")
            text = input("Enter data to write:")
            f = open(file_name, "w")
            f.write(text)
            f.close()            
            print("data written successfully")
            
        elif choice == 3:
            file_name = input("Enter file name with extension:")
            try:
                f = open(file_name, "r")
                print("file content:",f.read())
            except FileNotFoundError:
                print("file not exist, please enter correct file name")
                
        elif choice == 4:
            file_name = input("Enter file name with extension:")
            try:
                text = input("write something:")
                f = open(file_name, "a")
                f.write(text)
                f.close()
            except FileNotFoundError:
                 print("file not exist, please enter correct file name")

        elif choice == 5:
            return
        else:
            print("Enter correct choice")
            break



def modules():
    m = input("Enter module name to explore:")
    mode = __import__(m)
    print(f"available attributes in {m} module",dir(mode))



# modules()    
            
# file()   
# identifiers()
# randoms()       
# mathematcal_operator()
# date_time_operations()                    
modular_packager()
# Out:
# Try programiz.pro
# ...
# Welcome to Multi-utility Toolkit
# ...
#
# ---Main menu---
# choose an operation:
# 1. Date and Time operation
# 2. Mathematical operation
# 3. Random Data Generator
# 4. Generate unique identifiers(UUID)
# 5. File operations (custom module)
# 6. Explore module attributes (dir())
# 7. Exit
# Enter your choice: 4
# Generate unique identifiers:
# 165dac9e-ca80-4956-bab6-0662c01fcb5f
#
# ---Main menu---
# choose an operation:
# 1. Date and Time operation
# 2. Mathematical operation
# 3. Random Data Generator
# 4. Generate unique identifiers(UUID)
# 5. File operations (custom module)
# 6. Explore module attributes (dir())
# 7. Exit
# Enter your choice: 1
# Date and Time operation
# 1. Display current date and time
# 2. calculate difference between two dates
# 3. format date into custom format
# 4. stopwatch
# 5. countdown timer
# 6. back to main menu
# Enter your choice: 1
# Current date and time: 2025-09-16 11:00:59
#
# Date and Time operation
# ...
